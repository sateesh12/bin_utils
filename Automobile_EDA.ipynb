# %%
#Author  : Sateesh K
#Date.   : 05/Apr/2020
#Purpose : To Analyze the Automobile data set as part of assignement.

# %%
#Check if current working directory is as expected.
import os
print(os.getcwd())
# Out:
# C:\Users\SK00642740\SateeshK\src\py_utils

# %%
#Load the Automobile data-set
import pandas as pd
data = pd.read_csv('Automobile_data.txt')

# %%
#Take a look at the data read.
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
#Start an analysis for missing data
#After observing the data in an excel, the only special character in the data-set which needed handling was symbol ?

data = pd.read_csv('Automobile_data.txt',na_values="?")
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
#Collect stats on total missing values across all features.
print(data.isnull().sum())
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#Start cleaning up data column by column
#The first column which has NaN is num-of-doors
#Filter out this column based on NaN
#Make a copy of the original data-set for comparison purposes
df2 = data.copy()
df2.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
#Extract rows which has NaN in num-of-doors feature.
df2[df2['num-of-doors'].isnull()]
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 27          1              148.0  dodge       gas      turbo          NaN
# 63          0                NaN  mazda    diesel        std          NaN
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 27      sedan          fwd           front        93.7  ...           98
# 63      sedan          fwd           front        98.8  ...          122
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 27         mpfi  3.03    3.39               7.6      102.0    5500.0       24
# 63          idi  3.39    3.39              22.7       64.0    4650.0       36
#
#     highway-mpg    price
# 27           30   8558.0
# 63           42  10795.0
#
# [2 rows x 26 columns]

# %%
#Based on internet search on Dodge, it is only four door model, so replace num-of-doors to 4
df2.iloc[27]
#Replace the num-of-doors column in rwo 27
df2.iloc[27,5] = 'four'  #TBD how to handle this with non hard-coded row and column names !
df2.iloc[27]
df2.iloc[63,5] = 'four'

# %%
#Check if all NaN in num-of-doors coulumn are gone
print(df2.isnull().sum())
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#Go to next column of bore
#See the columns with NaN in bore
df2[df2['bore'].isnull()]
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 55          3              150.0  mazda       gas        std          two
# 56          3              150.0  mazda       gas        std          two
# 57          3              150.0  mazda       gas        std          two
# 58          3              150.0  mazda       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 55  hatchback          rwd           front        95.3  ...           70
# 56  hatchback          rwd           front        95.3  ...           70
# 57  hatchback          rwd           front        95.3  ...           70
# 58  hatchback          rwd           front        95.3  ...           80
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 55         4bbl   NaN     NaN               9.4      101.0    6000.0       17
# ...

# %%
#Seeing above data it is clear that all the mazda vehicle have a problem, now extract all mazda data to see how that looks
df2[df2['make'] == 'mazda']
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 50          1              104.0  mazda       gas        std          two
# 51          1              104.0  mazda       gas        std          two
# 52          1              104.0  mazda       gas        std          two
# 53          1              113.0  mazda       gas        std         four
# 54          1              113.0  mazda       gas        std         four
# 55          3              150.0  mazda       gas        std          two
# 56          3              150.0  mazda       gas        std          two
# 57          3              150.0  mazda       gas        std          two
# 58          3              150.0  mazda       gas        std          two
# 59          1              129.0  mazda       gas        std          two
# 60          0              115.0  mazda       gas        std         four
# 61          1              129.0  mazda       gas        std          two
# ...

# %%
#Based on internet search the borexstroke for Mazda is 89x100 mm which translates into 3.50x3.94 inches
#df1.loc[dates[0]:dates[1], 'E'] = 1
df2.loc[55:58,'bore'] = 3.50
df2.loc[55:58,'stroke'] = 3.93

# %%
#Verify if the bore and stroke values indeed changed.
df2[df2['make'] == 'mazda']
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 50          1              104.0  mazda       gas        std          two
# 51          1              104.0  mazda       gas        std          two
# 52          1              104.0  mazda       gas        std          two
# 53          1              113.0  mazda       gas        std         four
# 54          1              113.0  mazda       gas        std         four
# 55          3              150.0  mazda       gas        std          two
# 56          3              150.0  mazda       gas        std          two
# 57          3              150.0  mazda       gas        std          two
# 58          3              150.0  mazda       gas        std          two
# 59          1              129.0  mazda       gas        std          two
# 60          0              115.0  mazda       gas        std         four
# 61          1              129.0  mazda       gas        std          two
# ...

# %%
#Check if the NaN for bore and stroke are gone.
print(df2.isnull().sum())
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  0
# stroke                0
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# Now deal with horsepower  column.
df2[df2['horsepower'].isnull()]
# Out:
#      symboling  normalized-losses     make fuel-type aspiration num-of-doors  \
# 130          0                NaN  renault       gas        std         four
# 131          2                NaN  renault       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 130      wagon          fwd           front        96.1  ...          132
# 131  hatchback          fwd           front        96.1  ...          132
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 130         mpfi  3.46     3.9               8.7        NaN       NaN
# 131         mpfi  3.46     3.9               8.7        NaN       NaN
#
#     city-mpg  highway-mpg   price
# 130       23           31  9295.0
# 131       23           31  9895.0
#
# [2 rows x 26 columns]

# %%
#As can been seen the horsepower and peak-rpm both are for renault model
#Hence do a internet search to replace these values.
#As can been seen both have same engine specs of 132,3.46x3.9 which means horsepower and peak-rpm will be the same.
#Unable to figure out what type of engine, so let us see all renault models
df2[df2['make'] == 'renault']
# Out:
#      symboling  normalized-losses     make fuel-type aspiration num-of-doors  \
# 130          0                NaN  renault       gas        std         four
# 131          2                NaN  renault       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 130      wagon          fwd           front        96.1  ...          132
# 131  hatchback          fwd           front        96.1  ...          132
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 130         mpfi  3.46     3.9               8.7        NaN       NaN
# 131         mpfi  3.46     3.9               8.7        NaN       NaN
#
#     city-mpg  highway-mpg   price
# 130       23           31  9295.0
# 131       23           31  9895.0
#
# [2 rows x 26 columns]

# %%
#There are only two renaults, does not help much !
#Expand all columns to see if there is some other feature value which could be useful
df2.iloc[130]
# Out:
# symboling                  0
# normalized-losses        NaN
# make                 renault
# fuel-type                gas
# aspiration               std
# num-of-doors            four
# body-style             wagon
# drive-wheels             fwd
# engine-location        front
# wheel-base              96.1
# length                 181.5
# width                   66.5
# height                  55.2
# curb-weight             2579
# engine-type              ohc
# num-of-cylinders        four
# engine-size              132
# fuel-system             mpfi
# bore                    3.46
# stroke                   3.9
# compression-ratio        8.7
# horsepower               NaN
# peak-rpm                 NaN
# city-mpg                  23
# highway-mpg               31
# price                   9295
# Name: 130, dtype: object

# %%
#Based on intenet search it is safe to put in the following values:
#peak-rpm = 6000
#horsepower = 205kw
df2.loc[130:131,'peak-rpm'] = 6000
df2.loc[130:131,'horsepower'] = 205

# %%
#Verify of the NaN are in better shape.
print(df2.isnull().sum())
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  0
# stroke                0
# compression-ratio     0
# horsepower            0
# peak-rpm              0
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#Tacle price values which are NaN
df2[df2['price'].isnull()]
# Out:
#      symboling  normalized-losses     make fuel-type aspiration num-of-doors  \
# 9            0                NaN     audi       gas      turbo          two
# 44           1                NaN    isuzu       gas        std          two
# 45           0                NaN    isuzu       gas        std         four
# 129          1                NaN  porsche       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 9    hatchback          4wd           front        99.5  ...          131
# 44       sedan          fwd           front        94.5  ...           90
# 45       sedan          fwd           front        94.5  ...           90
# 129  hatchback          rwd           front        98.4  ...          203
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 9           mpfi  3.13    3.40               7.0      160.0    5500.0
# ...

# %%
#Check if the data set has other model prices which can be re-used
#Start with Audi.
df2[df2['make'] == 'audi']
# Out:
#    symboling  normalized-losses  make fuel-type aspiration num-of-doors  \
# 3          2              164.0  audi       gas        std         four
# 4          2              164.0  audi       gas        std         four
# 5          2                NaN  audi       gas        std          two
# 6          1              158.0  audi       gas        std         four
# 7          1                NaN  audi       gas        std         four
# 8          1              158.0  audi       gas      turbo         four
# 9          0                NaN  audi       gas      turbo          two
#
#   body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 3      sedan          fwd           front        99.8  ...          109
# 4      sedan          4wd           front        99.4  ...          136
# 5      sedan          fwd           front        99.8  ...          136
# 6      sedan          fwd           front       105.8  ...          136
# ...

# %%
#Based on average prices of Audi, plug in the values.
#df2.loc[9,'price'] = 38655
df2.loc[9,'price'] = df2[df2['make'] == 'audi'].mean()[15]

# %%
#Now tackle NaN in isuzu, first is to look if there are prices of othet isuzu in data-set
df2[df2['make'] == 'isuzu']
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 43          0                NaN  isuzu       gas        std         four
# 44          1                NaN  isuzu       gas        std          two
# 45          0                NaN  isuzu       gas        std         four
# 46          2                NaN  isuzu       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 43      sedan          rwd           front        94.3  ...          111
# 44      sedan          fwd           front        94.5  ...           90
# 45      sedan          fwd           front        94.5  ...           90
# 46  hatchback          rwd           front        96.0  ...          119
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 43         2bbl  3.31    3.23               8.5       78.0    4800.0       24
# ...

# %%
#Average the prices of existing values
type(df2[df2['make'] == 'isuzu'].mean())
df2[df2['make'] == 'isuzu'].mean()[15]
# Out:
# 8916.5

# %%
df2.loc[44:45,'price'] = df2[df2['make'] == 'isuzu'].mean()[15]

# %%
#verify if the isuzu prices did change indeed
df2[df2['make'] == 'isuzu']
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 43          0                NaN  isuzu       gas        std         four
# 44          1                NaN  isuzu       gas        std          two
# 45          0                NaN  isuzu       gas        std         four
# 46          2                NaN  isuzu       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 43      sedan          rwd           front        94.3  ...          111
# 44      sedan          fwd           front        94.5  ...           90
# 45      sedan          fwd           front        94.5  ...           90
# 46  hatchback          rwd           front        96.0  ...          119
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 43         2bbl  3.31    3.23               8.5       78.0    4800.0       24
# ...

# %%
#Now add the price of Porsche
#Look for other Porsche prices
df2[df2['make'] == 'porsche']
# Out:
#      symboling  normalized-losses     make fuel-type aspiration num-of-doors  \
# 125          3              186.0  porsche       gas        std          two
# 126          3                NaN  porsche       gas        std          two
# 127          3                NaN  porsche       gas        std          two
# 128          3                NaN  porsche       gas        std          two
# 129          1                NaN  porsche       gas        std          two
#
#       body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 125    hatchback          rwd           front        94.5  ...          151
# 126      hardtop          rwd            rear        89.5  ...          194
# 127      hardtop          rwd            rear        89.5  ...          194
# 128  convertible          rwd            rear        89.5  ...          194
# 129    hatchback          rwd           front        98.4  ...          203
#
# ...

# %%
# The porsche prices seem to be KWD and not in pounds, so best it to take average
df2[df2['make'] == 'porsche'].mean()[15]
# Out:
# 31400.5

# %%
#Copy the avg price into the NaN value.
df2.loc[129,'price'] = df2[df2['make'] == 'porsche'].mean()[15]

# %%
#Now verify if all the NaN in price columns are gone.
print(df2.isnull().sum())
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  0
# stroke                0
# compression-ratio     0
# horsepower            0
# peak-rpm              0
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
#Only one column normalized-losses has NaN value, not sure what this column means, hence ignoring this column
#in further data analysis
df3 = df2.drop('normalized-losses',axis=1)

# %%
print(df3)
# Out:
#      symboling         make fuel-type aspiration num-of-doors   body-style  \
# 0            3  alfa-romero       gas        std          two  convertible
# 1            3  alfa-romero       gas        std          two  convertible
# 2            1  alfa-romero       gas        std          two    hatchback
# 3            2         audi       gas        std         four        sedan
# 4            2         audi       gas        std         four        sedan
# ..         ...          ...       ...        ...          ...          ...
# 200         -1        volvo       gas        std         four        sedan
# 201         -1        volvo       gas      turbo         four        sedan
# 202         -1        volvo       gas        std         four        sedan
# 203         -1        volvo    diesel      turbo         four        sedan
# 204         -1        volvo       gas      turbo         four        sedan
#
# ...

# %%
print(df3.isnull().sum())
# Out:
# symboling            0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
#This proves that df3 is cleaned up data-set
#Write it to a file
df3.to_csv('Automotive_Cleaned_Dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-60c5ae9a1f9a> in <module>
#       1 #This proves that df3 is cleaned up data-set
#       2 #Write it to a file
# ----> 3 df3.to_csv('Automotive_Cleaned_Dataset.csv')
#
# NameError: name 'df3' is not defined

# %%
#Hypothesis 1 "As engine-size increase price also increase" 
import seaborn as sns
import os
sns.set(style='darkgrid')
engine_size_vs_price = sns.load_dataset("Automotive_Cleaned_Dataset",data_home=os.path.dirname(os.path.abspath("Automotive_Cleaned_Dataset")))
sns.relplot(x='engine-size', y='price', data = engine_size_vs_price)
#Hypothesis 2: As engine increases mileage per gallon decreases.
sns.relplot(x='engine-size', y='city-mpg',data = engine_size_vs_price)

#Hypothesis 3: Bigger the engine more is the weight of the car
sns.relplot(x='engine-size', y='curb-weight',data = engine_size_vs_price)

# %%
#Plot OEM name and number of models belonging to the brand.
import os
import pandas as pd
import matplotlib.pyplot as plt

#Business logic
df = pd.read_csv('Automotive_Cleaned_Dataset.csv')
#df.head()
oem_count = df['make'].value_counts()
type(oem_count)

#Graphics code for plotting.
oem_count.columns = ['make', 'num-of-models']
oem_count.plot(kind='bar',legend='True',grid='True')

# %%
#Hypothesis 5: as the volume of vehicle increase so does the weight.
#Compute the volume of the vehicle first.
df['vehicle-volume'] = df.apply(lambda row: (row.length*row.width*row.height)/10000,axis=1)
df.head()
#Add this into the persistent file so that it can be loaded into seaborn
df.to_csv('Automotive_Cleaned_Dataset_V1.csv')

#Now Seaboard plotting
import seaborn as sns
veh_size_to_weight = sns.load_dataset("Automotive_Cleaned_Dataset_V1",data_home=os.path.dirname(os.path.abspath("Automotive_Cleaned_Dataset_V1")))
sns.relplot(x='vehicle-volume', y='curb-weight', data = veh_size_to_weight)

#Hypothesis 6: city-mpg and highway-mpg are linearly dependent.
sns.relplot(x='city-mpg', y='highway-mpg', data = veh_size_to_weight)

# %%
#Hypothesis 7: Plot average price vs. manufacturer name.
df4 = df.groupby('make').mean()
df4 = df4.sort_values(['price'])
#Write this to a new version of datafile.
df4.to_csv('Automotive_Cleaned_Dataset_V2.csv')

#Now plotting using seaborn
import seaborn as sns
sns_data = sns.load_dataset("Automotive_Cleaned_Dataset_V2",data_home=os.path.dirname(os.path.abspath("Automotive_Cleaned_Dataset_V1")))
chart = sns.barplot(x='price',y='make', data = sns_data)
#chart.set_xticklabels(chart.get_xticklabels(), rotation=45,horizontalalignment='right')
